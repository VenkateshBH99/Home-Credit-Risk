# %%
from pipelines import aggregator_pipeline, fetch_dataset_pipeline, preprocessing_pipeline

# %%
fetch_dataset_pipeline.run_pipeline(check_existing=True)
# Out:
# Fetching dataset from: https://drive.google.com/drive/folders/1rGwpgGk-XODILNLoh0tcsvC1MvwVq5ga
# Retrieving folder contents
# Processing file 1F6dUhXExu43dz4OOxnx7TgbTysqi2Tbf application_test.csv
# Processing file 1OBZ5zwn1pbCHFUaWZYoV_eIVAtLMojFf application_train.csv
# Processing file 1wHn9lvxeFcZMzXcbRtf-dPmaL7JE41Cb bureau.csv
# Processing file 17xUzLcM75CmMPJ2XqexCS2J7Xrn-LZvK bureau_balance.csv
# Processing file 1BbSUi_SLc9JKHpCY_h76W--G1zQpRgOS credit_card_balance.csv
# Processing file 1uAi5sVIkx9ix0s0_GIaUUPALhB5ArE_d HomeCredit_columns_description.csv
# Processing file 1xHnng0czkednoQZFlqOFPH7NbLcVF0Eg installments_payments.csv
# Processing file 1QWd2feGz2LklPFNHetsOeWiikvVEi2NF POS_CASH_balance.csv
# Processing file 1V0C5ZtfQ9TO7UuKWuP_Pj1loBz4qhRFD previous_application.csv
# Processing file 1UrHaciOYpvtRDSvY_vp1JxNZGG83v3ON sample_submission.csv
#
# Done. Files saved to: dataset/original/
# Retrieving folder contents completed
# Building directory structure
# ...

# %%
aggregator_pipeline.run_pipeline(check_existing=True)
# Out:
# Running TRADITIONAL aggregator pipeline (application data only)...
#
# Traditional aggregated files already exist. Skipping pipeline.
# Running COMBINED aggregator pipeline (all tables aggregated)...
#
# Combined aggregated files already exist. Skipping pipeline.

# %%
preprocessing_pipeline.run_pipeline(check_existing=False)
# Out:
# ...
# Running TRADITIONAL preprocessing pipeline (pca)...
# ...
#
# Step 1/7: Loading traditional splits...
#    train.csv                      ->    215,257 rows x 128 cols
#    validation.csv                 ->     46,127 rows x 128 cols
#    test.csv                       ->     46,127 rows x 128 cols
#
# Step 2/7: Imputation (fit on train)...
#    Imputer (median) fitted on train: 82 column(s) targeted.
#    [train] Safety fillna(0): 573,802 residual NaN(s) cleared.
#    [val] Safety fillna(0): 123,002 residual NaN(s) cleared.
#    [test] Safety fillna(0): 122,945 residual NaN(s) cleared.
#
# Step 2b/7: Categorical imputation (fit on train)...
#    No categorical columns required imputation.
#    [train] No categorical imputation needed.
#    [val] No categorical imputation needed.
#    [test] No categorical imputation needed.
#
# Step 3/7: Low-variance column removal (fit on train)...
#    Dropping 49 low-variance column(s) (threshold=0.01):
# ...
